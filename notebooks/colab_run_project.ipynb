# %% [markdown]
# # Project J: LLM-as-Judge — Colab Runner

# %%
# !unzip llm_as_judge_project.zip -d /content/
# %cd /content/llm_as_judge_project

# %%
# !pip install -q -r requirements.txt

# %%
# Quick test, no GPU needed
# !python -m src.llm_judge.run_experiment --config configs/default.yaml --backend heuristic

# %%
# !python -m src.llm_judge.run_experiment --config configs/default.yaml --backend hf --model google/flan-t5-small
# !python -m src.llm_judge.run_experiment --config configs/default.yaml --backend hf --model google/flan-t5-base

# %%
import pandas as pd
display(pd.read_csv('results/summary_metrics.csv'))
display(pd.read_csv('results/bias_report.csv'))

# %%
from IPython.display import Image, display
display(Image('results/accuracy_by_mode.png'))
display(Image('results/bias_summary.png'))
